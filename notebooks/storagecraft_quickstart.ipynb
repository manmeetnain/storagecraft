# %% [markdown]
# # StorageCraft Python quickstart
# Compare protection, performance, RAG storage, and GPU memory with transparent dependency-free models.

# %%
from storagecraft_tools import calculate_raid, compare_raids, erasure_coding, nvme_queues, rag_storage, gpu_memory
calculate_raid('raid6', 8, 4).as_dict()

# %%
[x for x in compare_raids(16, 4, groups=2) if 'usable_tb' in x]

# %%
erasure_coding(data=10, parity=4, dataset_tb=100, failures=2)

# %%
nvme_queues(queues=8, depth=32, latency_us=100, device_iops=1_000_000, host_iops=800_000)

# %%
rag_storage(documents=1_000_000, avg_tokens=1200, chunk_tokens=512)

# %%
gpu_memory(params_b=70, weight_bits=4, layers=80, kv_heads=8, head_dim=128, tokens=8192, concurrency=8)
